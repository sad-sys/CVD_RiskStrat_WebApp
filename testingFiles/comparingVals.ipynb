# %%
import pandas as pd
import numpy as np

# %%
categories = pd.read_csv("/Users/sadiqkhawaja/Downloads/final_questionnaire_features.csv")
mappingFile = pd.read_csv("/Users/sadiqkhawaja/Desktop/PhD/AoU_UKB/Categories_RewriteAllQuestionsAutoSaveCSV.csv")
mappingFile = mappingFile.drop(columns="Category")

# %%
categories = categories.rename(columns={"Unnamed: 0":"Predictor"})
categories = categories[["Predictor","Category"]]

# %%
mergedDF = pd.merge(categories,mappingFile, on="Predictor",how="outer")
mergedDF
# Out:
#                            Predictor              Category  \
# 0     Able.to.confide...Instance.0_0  Psychosocial factors
# 1     Able.to.confide...Instance.0_1                   NaN
# 2     Able.to.confide...Instance.0_2  Psychosocial factors
# 3     Able.to.confide...Instance.0_3  Psychosocial factors
# 4     Able.to.confide...Instance.0_4  Psychosocial factors
# ...                              ...                   ...
# 1387                             NaN                   NaN
# 1388                             NaN                   NaN
# 1389                             NaN                   NaN
# 1390                             NaN                   NaN
# 1391                             NaN                   NaN
#
#                     Data-coding                                   Source  \
# 0     0 : Never or almost never  Questionnaire/Interview at recruitment
# 1     1 : Once every few months  Questionnaire/Interview at recruitment
# ...
