# %%
import joblib
import pandas as pd
import numpy as np

# %%
imputer = joblib.load("/Users/sadiqkhawaja/Desktop/PhD/CVD_RiskStrat_WebApp-merge-interface2/model_files/imputers/health_and_medical_history_noDrop_rf.pkl")
scaler = joblib.load("/Users/sadiqkhawaja/Desktop/PhD/CVD_RiskStrat_WebApp-merge-interface2/model_files/scalers/health_and_medical_history_noDropscaler.pkl")
model = joblib.load("/Users/sadiqkhawaja/Desktop/PhD/CVD_RiskStrat_WebApp-merge-interface2/model_files/ML_models/MRMR_COX_Sociodemographics_Health_and_medical_history.pkl")
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.6.1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator RandomForestRegressor from version 1.6.1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
sampleCols = list(imputer.feature_names_in_)
sample = pd.DataFrame(columns=sampleCols)
sample
# Out:
# Empty DataFrame
# ...

# %%
# Step 1: Create empty row using your sample columns
sample_df = pd.DataFrame(columns=sample.columns)
row = pd.Series(np.nan, index=sample.columns)

backend_values = {
    "category_Sociodemographics_ts_Length.of.time.at.current.address...Instance.0": 21.0,
    "category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_1": 1,
    "category_Sociodemographics_ts_Gas.or.solid.fuel.cooking.heating...Instance.0_1": 1,
    "category_Sociodemographics_ts_Number.in.household...Instance.0_Middle.third": 1,
    "category_Sociodemographics_ts_How.are.people.in.household.related.to.participant...Instance.0_4": 1,
    "category_Sociodemographics_ts_How.are.people.in.household.related.to.participant...Instance.0_5": 1,
    "category_Sociodemographics_ts_Number.of.vehicles.in.household...Instance.0_4": 1,
    "category_Sociodemographics_ts_Average.total.household.income.before.tax...Instance.0_2": 1,
    "category_Sociodemographics_ts_Current.employment.status...Instance.0_7": 1,
    "category_Sociodemographics_ts_Frequency.of.travelling.from.home.to.job.workplace...Instance.0_Lower.third": 1,
    "category_Sociodemographics_ts_Distance.between.home.and.job.workplace...Instance.0_Middle.third": 1,
    "category_Sociodemographics_ts_Time.employed.in.main.current.job...Instance.0_Lower.third": 1,
    "category_Sociodemographics_ts_Length.of.working.week.for.main.job...Instance.0_Middle.third": 1,
    "category_Sociodemographics_ts_Transport.type.for.commuting.to.job.workplace...Instance.0_3": 1,
    "category_Sociodemographics_ts_Transport.type.for.commuting.to.job.workplace...Instance.0_2": 1,
    "category_Sociodemographics_ts_Job.involves.mainly.walking.or.standing...Instance.0_1": 1,
    "category_Sociodemographics_ts_Job.involves.heavy.manual.or.physical.work...Instance.0_1": 1,
    "category_Sociodemographics_ts_Job.involves.shift.work...Instance.0_1": 1,
    "category_Sociodemographics_ts_Job.involves.night.shift.work...Instance.0_1": 1,
    "category_Sociodemographics_ts_Qualifications...Instance.0_1": 1,
    "category_Sociodemographics_ts_Qualifications...Instance.0_2": 1,
    "category_Sociodemographics_ts_Qualifications...Instance.0_3": 1,
    "category_Sociodemographics_ts_Age.completed.full.time.education...Instance.0_Lower.third": 1,
    "category_Sociodemographics_ts_Ethnic.background...Instance.0_3001": 1,

    "category_Health and medical history_ts_Wears.glasses.or.contact.lenses...Instance.0_1": 1,
    "category_Health and medical history_ts_Overall.health.rating...Instance.0_2": 1,
    "category_Health and medical history_ts_Long.standing.illness..disability.or.infirmity...Instance.0_0": 1,
    "category_Health and medical history_ts_Falls.in.the.last.year...Instance.0_1": 1,
    "category_Health and medical history_ts_Weight.change.compared.with.1.year.ago...Instance.0_0": 1,
    "category_Health and medical history_ts_Wheeze.or.whistling.in.the.chest.in.last.year...Instance.0_0": 1,
    "category_Health and medical history_ts_Age.asthma.diagnosed...Instance.0_Lower.third": 1,
    "category_Health and medical history_ts_Combined.sex.medication_neg7": 1,

    "Age.at.recruitment": 23.0
}

# Step 3: Fill row
for key, value in backend_values.items():
    if key in row.index:
        row[key] = value
    else:
        print(f"⚠️ Missing column in sample: {key}")

# Step 4: Convert to DataFrame
final_input = pd.DataFrame([row])

print(final_input.shape)  # should be (1, 96)
# Out:
# ⚠️ Missing column in sample: Age.at.recruitment
# (1, 241)

# %%
final_input
# Out:
#    category_Sociodemographics_ts_Length.of.time.at.current.address...Instance.0  \
# 0                                               21.0
#
#    category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_2  \
# 0                                                NaN
#
#    category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_1  \
# 0                                                1.0
#
#    category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_4  \
# 0                                                NaN
#
#    category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_neg7  \
# 0                                                NaN
#
#    category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_3  \
# 0                                                NaN
#
#    category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_5  \
# 0                                                NaN
#
# ...

# %%
final_inputImputed = imputer.transform(final_input)
final_inputImputed_Scaled = scaler.transform(final_inputImputed)
# Out:
# [IterativeImputer] Completing matrix with shape (1, 241)
# [IterativeImputer] Ending imputation round 1/3, elapsed time 3.02
# [IterativeImputer] Ending imputation round 2/3, elapsed time 5.97
# [IterativeImputer] Ending imputation round 3/3, elapsed time 8.92

# %%
final_inputImputed_Scaled
# Out:
# array([[ 2.63157895e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -8.85982872e-02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          5.86207492e-01,  0.00000000e+00,  1.59962637e-01,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.54955396e-01,  6.17735465e-01,  2.74547722e-03,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.75757576e-01,
#          2.91765180e-01,  2.13627204e-03,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %%
print(model.predict(final_inputImputed_Scaled))
# Out:
# [3.47426419]
# /opt/homebrew/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but CoxPHSurvivalAnalysis was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# Data from Supplementary Table 4 (CVD)
strategies = [
    "2-Step NHS HC\n(>5%)",
    "2-Step NHS HC\n+ Omics",
    "1-Step NHS HC",
    "1-Step NHS HC\n+ PMH"
]

burden = [35.8, 35.8, 100, 100]
c_index = [0.741, 0.746, 0.736, 0.750]

# Just make it wider
fig, ax = plt.subplots(figsize=(12, 4.5))

ax.scatter(burden, c_index, s=150)

for x, y, label in zip(burden, c_index, strategies):
    ax.annotate(
        label,
        (x, y),
        xytext=(8, 5),
        textcoords="offset points",
        fontsize=10
    )

# Arrow showing burden reduction
ax.annotate(
    "",
    xy=(35.8, 0.734),
    xytext=(100, 0.734),
    arrowprops=dict(arrowstyle="<->", lw=1.5)
)

ax.text(
    67.9,
    0.733,
    "64.2% fewer NHS Health Checks",
    ha="center",
    fontsize=10
)

ax.set_xlabel("Participants Requiring NHS Health Check (%)")
ax.set_ylabel("Harrell's C-index")
ax.set_title("Efficiency Frontier: Screening Burden vs Discrimination")

ax.set_xlim(20, 110)
ax.set_ylim(0.730, 0.755)

# Remove grid
# ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
imputer.feature_names_in_
# Out:
# array(['category_Sociodemographics_ts_Length.of.time.at.current.address...Instance.0',
#        'category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_2',
#        'category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_1',
#        'category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_4',
#        'category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_neg7',
#        'category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_3',
#        'category_Sociodemographics_ts_Type.of.accommodation.lived.in...Instance.0_5',
#        'category_Sociodemographics_ts_Own.or.rent.accommodation.lived.in...Instance.0_2',
#        'category_Sociodemographics_ts_Own.or.rent.accommodation.lived.in...Instance.0_1',
#        'category_Sociodemographics_ts_Own.or.rent.accommodation.lived.in...Instance.0_3',
#        'category_Sociodemographics_ts_Own.or.rent.accommodation.lived.in...Instance.0_5',
# ...
